# %%
import pandas as pd
import numpy as np

import InfoTrayectosModule as Trayectos
from DecoderModule import Decoder
import InfoStationsModule as Stations

# %%
Decode = Decoder('../Files/IndiceBases.xlsx')
Decode.infoStation('Lavapiés')
# Out:
# id                              57
# name             Plaza de Lavapiés
# total_bases                     24
# number                          53
# longitude                 -3.70088
# latitude                   40.4089
# address        Calle Valencia nº 1
# Name: 117, dtype: object

# %%
filePath = "../Files/Bicimad_Stations_201905.json"
Stations.getCleanDataframe(filePath)
# Out:
# _id                          2019-05-01 00:20:28.426371  \
# stations Name
# 1        reservations_count                         0.0
# 2        reservations_count                         0.0
# 3        reservations_count                         0.0
# 4        reservations_count                         0.0
# 5        reservations_count                         0.0
# ...                                                 ...
# 173      dock_bikes                                 7.0
# 174      dock_bikes                                 5.0
# 175      dock_bikes                                 7.0
# 190      dock_bikes                                 NaN
# 211      dock_bikes                                 NaN
#
# _id                          2019-05-01 01:20:29.224701  \
# stations Name
# 1        reservations_count                         0.0
# 2        reservations_count                         0.0
# 3        reservations_count                         0.0
# ...

# %%
filePath = "../Files/201905_Usage_Bicimad.json"
Tracks = Trayectos.getCleanDataframe(filePath)

# %%
Tracks.head()
# Out:
#                         _id  \
# 0  5ccf5dd72f3843802e9afe76
# 1  5ccf5dd72f3843802e9afe7c
# 2  5ccf5dd72f3843802e9afe7d
# 3  5ccf5dd72f3843802e9afe82
# 4  5ccf5dd72f3843802e9afe83
#
#                                        user_day_code  idplug_base  \
# 0  e4f17c74a759e69002023f3a76ba9f25cf1ea331de53bc...           12
# 1  c7b1ba68d8bcb1668bbef4af5b2e55bfcd613c2104cd2c...           24
# 2  2c5346091af6fa3901b6c5d03d5d3ec228508cd6fdb44b...            3
# 3  69140c599217deeec84230437bc512ce58f771c32a1c69...            9
# 4  81e793f5935a658dddd5d695c29449b2f5479066bcc5f2...           18
#
#                                                track  user_type  \
# 0  {'type': 'FeatureCollection', 'features': [{'g...          1
# 1  {'type': 'FeatureCollection', 'features': [{'g...          1
# 2  {'type': 'FeatureCollection', 'features': [{'g...          1
# 3  {'type': 'FeatureCollection', 'features': [{'g...          1
# 4  {'type': 'FeatureCollection', 'features': [{'g...          1
#
# ...
